# %%
import random
import time
import pickle
import numpy as np

t = []
tt = []
data = []
def holdout_split(sample_sequences, hold_out_perc=80):
    # This function returns the random holdout split for the given data

    # Ar first you shuffle the data
    random.shuffle(sample_sequences)

    # You compute the length and the size of the split
    length = len(sample_sequences)
    train_length = int(length * hold_out_perc / 100)

    test_set = []
    train_set = []
    n = 0

    # We pick the first train_length lines for the train_set and the resting for the testing
    for i in sample_sequences:
        if n < train_length:
            train_set.append(i)
        else:
            test_set.append(i)

        n = n + 1

    return train_set, test_set


def split_sets(train_set, test_set):
    # This function returns the two sets: inputs, targets

    X_tr = []
    Y_tr = []
    for t in train_set:
        X_tr.append(t[0])
        Y_tr.append(t[1])

    X_te = []
    Y_te = []
    for t in train_set:
        X_te.append(t[0])
        Y_te.append(t[1])

    return np.array(X_tr), np.array(Y_tr), np.array(X_te), np.array(Y_te)


def main():
    file = open('splits/split_100_30d_1d_100.txt', 'rb')
    ss, countries_number = pickle.load(file)
    file.close()
    global t
    global tt
    t, tt = holdout_split(ss)
    global data
    data = split_sets(t, tt)

# %%
import matplotlib.pyplot as plt
main()

# %%
d = []
for i in data[0]:
    a = np.transpose(i)
    if(np.sum(a) >= -0.3):
        d.append(a)
size = len(d)
for i in range(0,53):
    plt.plot(d[0][i])
plt.ylabel('one time series')
plt.show()

# %%
names = {1:'Colombia',51:'Mexico', 11:'Argentina',0:'China',7:'Italy',17:'Spain',53:'Uk', 48:'USA'}
for i in [1,11,51,7,17,53,48]:
    plt.plot(d[0][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [1,11,51]:
    plt.plot(d[0][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [17,7]:
    plt.plot(d[0][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [53,48]:
    plt.plot(d[0][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [1,11,51,7,17,53,48]:
    plt.plot(d[4][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [1,11,51]:
    plt.plot(d[4][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [7,17]:
    plt.plot(d[4][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [53,48]:
    plt.plot(d[4][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [1,11,51,7,17,53,48]:
    plt.plot(d[2][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [1,11,51]:
    plt.plot(d[2][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [7,17]:
    plt.plot(d[2][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [53,48]:
    plt.plot(d[2][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
