# %%
import random
import time
import pickle
import numpy as np

file = open(dump_folder + "/" + description + ".txt", 'rb')
                selected_points, countries_number = pickle.load(file)
                file.close()
    file = open('../data/sequences/Despacito_200_1_1_200.txt', 'rb')
    selected_points, countries_number = pickle.load(file)
    file.close()

# %%
import matplotlib.pyplot as plt
main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-24087256dfd9> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 main()
#
# <ipython-input-1-f480aa74e9aa> in main()
#      53 def main():
#      54     file = open('../data/sequences/Despacito_200_1_1_200.txt', 'rb')
# ---> 55     selected_points, countries_number = pickle.load(file)
#      56     file.close()
#
# /Users/nicolovendramin/miniconda3/envs/res_meth/lib/python2.7/pickle.pyc in load(file)
#    1382
#    1383 def load(file):
# -> 1384     return Unpickler(file).load()
#    1385
#    1386 def loads(str):
#
# /Users/nicolovendramin/miniconda3/envs/res_meth/lib/python2.7/pickle.pyc in load(self)
#     862             while 1:
#     863                 key = read(1)
# --> 864                 dispatch[key](self)
#     865         except _Stop, stopinst:
# ...

# %%
d = []
for i in data[0]:
    a = np.transpose(i)
    if(np.sum(a) >= -0.3):
        d.append(a)
size = len(d)
for i in range(0,53):
    plt.plot(d[0][i])
plt.ylabel('one time series')
plt.show()

# %%
names = {1:'Colombia',51:'Mexico', 11:'Argentina',0:'China',7:'Italy',17:'Spain',53:'Uk', 48:'USA'}
for i in [1,11,51,7,17,53,48]:
    plt.plot(d[0][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [1,11,51]:
    plt.plot(d[0][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [17,7]:
    plt.plot(d[0][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [53,48]:
    plt.plot(d[0][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [1,11,51,7,17,53,48]:
    plt.plot(d[12][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [1,11,51]:
    plt.plot(d[12][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [7,17]:
    plt.plot(d[12][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [53,48]:
    plt.plot(d[12][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [1,11,51,7,17,53,48]:
    plt.plot(d[16][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [1,11,51]:
    plt.plot(d[16][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [7,17]:
    plt.plot(d[16][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
for i in [53,48]:
    plt.plot(d[16][i], label=names[i])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
